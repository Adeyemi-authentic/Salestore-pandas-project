# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\SalesStore.csv")

# %%
df
# Out:
#     Order_Date  Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0    2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10022901
# 1    2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10023012
# 2    2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10002828
# 3    2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10022901
# 4    2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10000482
# ..         ...        ...       ...          ...      ...               ...
# 211   1/9/2024  1/14/2024    Ground        20004     East  ELE-PRI-10021890
# 212   1/9/2024  1/14/2024    Ground        20004     East  ELE-PRI-10022901
# 213   1/9/2024  1/14/2024    Ground        20004     East  ELE-PRI-10002727
# 214   1/9/2024  1/14/2024    Ground        20004     East  ELE-PRI-10021890
# 215   1/9/2024  1/14/2024    Ground        20004     East  ELE-PRI-10000481
#
# ...

# %%
df.head(10)
# Out:
#   Order_Date  Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0  2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10022901
# 1  2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10023012
# 2  2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10002828
# 3  2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10022901
# 4  2/15/2021  2/20/2021    Ground        44104  Midwest  OFF-TAP-10000482
# 5  3/10/2021  3/15/2021       Air        75201    South   FUR-CH-10000454
# 6  3/10/2021  3/15/2021       Air        75201    South   FUR-CH-10000454
# 7  3/10/2021  3/15/2021       Air        75201    South   FUR-CH-10000454
# 8  3/10/2021  3/15/2021       Air        75201    South   FUR-CH-10000454
# 9  3/10/2021  3/15/2021       Air        75201    South   FUR-CH-10000454
#
#           Category Sub_Category  Sales  Quantity  Profit State
# 0  Office Supplies         Tape      5         1    0.15    OH
# ...

# %%
df.columns
# Out:
# Index(['Order_Date', 'Ship_Date', 'Ship_Mode', 'Postal_Code', 'Region',
#        'Product_Reference', 'Category', 'Sub_Category', 'Sales', 'Quantity',
#        'Profit', 'State'],
#       dtype='object')

# %%
df.set_index('Category',inplace=True)

# %%
df
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  \
# Category
# Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# ...                    ...        ...       ...          ...      ...
# Electronics       1/9/2024  1/14/2024    Ground        20004     East
# Electronics       1/9/2024  1/14/2024    Ground        20004     East
# Electronics       1/9/2024  1/14/2024    Ground        20004     East
# Electronics       1/9/2024  1/14/2024    Ground        20004     East
# Electronics       1/9/2024  1/14/2024    Ground        20004     East
#
#                 Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#             Category Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  \
# 0    Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# 1    Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# 2    Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# 3    Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# 4    Office Supplies  2/15/2021  2/20/2021    Ground        44104  Midwest
# ..               ...        ...        ...       ...          ...      ...
# 211      Electronics   1/9/2024  1/14/2024    Ground        20004     East
# 212      Electronics   1/9/2024  1/14/2024    Ground        20004     East
# 213      Electronics   1/9/2024  1/14/2024    Ground        20004     East
# 214      Electronics   1/9/2024  1/14/2024    Ground        20004     East
# 215      Electronics   1/9/2024  1/14/2024    Ground        20004     East
#
#     Product_Reference Sub_Category  Sales  Quantity  Profit State
# ...

# %%
# regions that have the highest sales and quantity

# %%
df.groupby('Region')

# %%
df.groupby('Region')[['Sales','Quantity']].max()
# Out:
#          Sales  Quantity
# Region
# East       700         4
# Midwest    800         4
# South      900         4
# West       450         4

# %%
df.groupby('Region')[['Quantity']].count()
# Out:
#          Quantity
# Region
# East           30
# Midwest        61
# South          76
# West           49

# %%
# to get what they bought in the region and quantities

# %%
df.groupby(['Region','Sub_Category'])[['Quantity']].count()
# Out:
#                            Quantity
# Region  Sub_Category
# East    Cameras                   5
#         Headphones                4
#         Pens                      6
#         Printers                  5
#         Scissors                  6
#         Smartphones               4
# Midwest Bookcases                10
#         Desks                     5
#         Glue                      5
#         Laptops                   6
#         Lighting                  5
#         Markers                   6
#         Pencils                   4
#         Printers                  6
#         Staplers                  4
#         Storage                   5
#         Tape                      5
# South   Accessories               5
#         Beds                      6
#         Chairs                    7
#         Laptops                   4
#         Monitors                  6
#         Outdoor Furniture         5
#         Paper                     6
# ...

# %%
# to know the max.sales of item and quantity

# %%
df.groupby(['Region','Sub_Category'])[['Sales','Quantity']].max()
# Out:
#                            Sales  Quantity
# Region  Sub_Category
# East    Cameras              600         3
#         Headphones           180         1
#         Pens                  50         4
#         Printers             300         4
#         Scissors              25         1
#         Smartphones          700         3
# Midwest Bookcases            600         4
#         Desks                450         1
#         Glue                  10         4
#         Laptops              800         2
#         Lighting             180         2
#         Markers               20         1
#         Pencils               15         2
#         Printers             280         4
#         Staplers              25         3
#         Storage              250         1
#         Tape                   5         1
# South   Accessories          100         1
#         Beds                 900         4
#         Chairs               500         3
# ...

# %%
df.groupby(['Region','Sub_Category'])[['Sales','Quantity']].min()
# Out:
#                            Sales  Quantity
# Region  Sub_Category
# East    Cameras              600         3
#         Headphones           180         1
#         Pens                  50         4
#         Printers             300         4
#         Scissors              25         1
#         Smartphones          700         3
# Midwest Bookcases            550         3
#         Desks                450         1
#         Glue                  10         4
#         Laptops              800         2
#         Lighting             180         2
#         Markers               20         1
#         Pencils               15         2
#         Printers             280         4
#         Staplers              25         3
#         Storage              250         1
#         Tape                   5         1
# South   Accessories          100         1
#         Beds                 900         4
#         Chairs               200         2
# ...

# %%
# to know amount generated from each item

# %%
df.groupby('Sub_Category')[['Sales']]

# %%
df.groupby('Sub_Category')[['Sales']].sum()
# Out:
#                    Sales
# Sub_Category
# Accessories          500
# Beds                5400
# Bookcases           5800
# Cameras             3000
# Chairs              3800
# Desks               4350
# Envelopes             75
# Erasers               60
# Glue                  50
# Headphones          1620
# Laptops             8200
# Lighting             900
# Markers              120
# Monitors            2100
# Notebooks           1120
# Outdoor Furniture   2750
# Paper                600
# Pencils               60
# Pens                 300
# Phones              2000
# Printers            3180
# Rulers                40
# Scissors             150
# Smartphones         2800
# Smartwatches        1200
# Sofas               4200
# Speakers             600
# Staplers             280
# Storage             1250
# Tables              3600
# Tablets             2700
# Tape                  25

# %%
df.groupby('Sub_Category')[['Sales']].sum().sort_values(by=['Sales'],ascending=False)
# Out:
#                    Sales
# Sub_Category
# Laptops             8200
# Bookcases           5800
# Beds                5400
# Desks               4350
# Sofas               4200
# Chairs              3800
# Tables              3600
# Printers            3180
# Cameras             3000
# Smartphones         2800
# Outdoor Furniture   2750
# Tablets             2700
# Monitors            2100
# Phones              2000
# Headphones          1620
# Storage             1250
# Smartwatches        1200
# Notebooks           1120
# Lighting             900
# Speakers             600
# Paper                600
# Accessories          500
# Pens                 300
# Staplers             280
# Scissors             150
# Markers              120
# Envelopes             75
# Pencils               60
# Erasers               60
# Glue                  50
# Rulers                40
# Tape                  25

# %%
# or we can do it this way also

# %%
df_sum=df.groupby('Sub_Category')[['Sales']].sum()

# %%
df_sum
# Out:
#                    Sales
# Sub_Category
# Accessories          500
# Beds                5400
# Bookcases           5800
# Cameras             3000
# Chairs              3800
# Desks               4350
# Envelopes             75
# Erasers               60
# Glue                  50
# Headphones          1620
# Laptops             8200
# Lighting             900
# Markers              120
# Monitors            2100
# Notebooks           1120
# Outdoor Furniture   2750
# Paper                600
# Pencils               60
# Pens                 300
# Phones              2000
# Printers            3180
# Rulers                40
# Scissors             150
# Smartphones         2800
# Smartwatches        1200
# Sofas               4200
# Speakers             600
# Staplers             280
# Storage             1250
# Tables              3600
# Tablets             2700
# Tape                  25

# %%
df_sum.sort_values(by='Sales',ascending=False)
# Out:
#                    Sales
# Sub_Category
# Laptops             8200
# Bookcases           5800
# Beds                5400
# Desks               4350
# Sofas               4200
# Chairs              3800
# Tables              3600
# Printers            3180
# Cameras             3000
# Smartphones         2800
# Outdoor Furniture   2750
# Tablets             2700
# Monitors            2100
# Phones              2000
# Headphones          1620
# Storage             1250
# Smartwatches        1200
# Notebooks           1120
# Lighting             900
# Speakers             600
# Paper                600
# Accessories          500
# Pens                 300
# Staplers             280
# Scissors             150
# Markers              120
# Envelopes             75
# Pencils               60
# Erasers               60
# Glue                  50
# Rulers                40
# Tape                  25

# %%
# we can now make the df_sum to be another variable

# %%
df_sort=df_sum.sort_values(by='Sales',ascending=False)

# %%
df_sort
# Out:
#                    Sales
# Sub_Category
# Laptops             8200
# Bookcases           5800
# Beds                5400
# Desks               4350
# Sofas               4200
# Chairs              3800
# Tables              3600
# Printers            3180
# Cameras             3000
# Smartphones         2800
# Outdoor Furniture   2750
# Tablets             2700
# Monitors            2100
# Phones              2000
# Headphones          1620
# Storage             1250
# Smartwatches        1200
# Notebooks           1120
# Lighting             900
# Speakers             600
# Paper                600
# Accessories          500
# Pens                 300
# Staplers             280
# Scissors             150
# Markers              120
# Envelopes             75
# Pencils               60
# Erasers               60
# Glue                  50
# Rulers                40
# Tape                  25

# %%
# to get the top 5 

df_sort.head(5)
# Out:
#               Sales
# Sub_Category
# Laptops        8200
# Bookcases      5800
# Beds           5400
# Desks          4350
# Sofas          4200

# %%
df.groupby(['Category','Sub_Category'])[['Sales','Quantity','Profit']].agg({'Sales':['max','min','sum','count'],
                                                                           'Quantity':['max','min','sum','count'],
                                                                           'Profit':['max','min','sum','count']})
# Out:
#                                   Sales                  Quantity          \
#                                     max  min   sum count      max min sum
# Category        Sub_Category
# Electronics     Accessories         100  100   500     5        1   1   5
#                 Cameras             600  600  3000     5        3   3  15
#                 Headphones          180  150  1620    10        3   1  22
#                 Laptops             850  800  8200    10        4   2  28
#                 Monitors            350  350  2100     6        3   3  18
#                 Phones              500  500  2000     4        2   2   8
#                 Printers            300  280  3180    11        4   4  44
#                 Smartphones         700  700  2800     4        3   3  12
#                 Smartwatches        200  200  1200     6        1   1   6
#                 Speakers            120  120   600     5        2   2  10
# ...

# %%
df_profit=df.groupby('Category')[['Profit']]

# %%
df_profit.sum()
# Out:
#                  Profit
# Category
# Electronics      558.00
# Furniture        641.00
# Office Supplies   63.15

# %%
df_profit.sum().plot(kind='pie',y='Profit',figsize=(8,8))
# Out:
# <Axes: ylabel='Profit'>

# %%
df_sales=df.groupby('Category')[['Sales']].sum()

# %%
df_sales
# Out:
#                  Sales
# Category
# Electronics      27900
# Furniture        32050
# Office Supplies   2880

# %%
df_sales.plot.barh(stacked=True, color='green')
# Out:
# <Axes: ylabel='Category'>

# %%
df_quantity=df.groupby('Category')['Quantity'].max()

# %%
df_quantity.plot(kind='bar',title='max quantity by category',color='blue')
# Out:
# <Axes: title={'center': 'max quantity by category'}, xlabel='Category'>

# %%
df.groupby('Category')['Quantity'].count()
# Out:
# Category
# Electronics        72
# Furniture          71
# Office Supplies    73
# Name: Quantity, dtype: int64

# %%
df_qua=df.groupby('Category')['Quantity'].count()

# %%
df_qua
# Out:
# Category
# Electronics        72
# Furniture          71
# Office Supplies    73
# Name: Quantity, dtype: int64

# %%
df_qua.plot(kind='pie',y='Quantity')
# Out:
# <Axes: ylabel='Quantity'>

# %%
df_qua.transpose()
# Out:
# Category
# Electronics        72
# Furniture          71
# Office Supplies    73
# Name: Quantity, dtype: int64

# %%
df_qua.plot(kind='bar',title='total quantities',color='grey')
# Out:
# <Axes: title={'center': 'total quantities'}, xlabel='Category'>

# %%
df.columns
# Out:
# Index(['Category', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Postal_Code',
#        'Region', 'Product_Reference', 'Sub_Category', 'Sales', 'Quantity',
#        'Profit', 'State'],
#       dtype='object')

# %%
ddf=df[['State','Sales','Quantity','Order_Date','Category']]

# %%
ddf
# Out:
#     State  Sales  Quantity Order_Date         Category
# 0      OH      5         1  2/15/2021  Office Supplies
# 1      OH      5         1  2/15/2021  Office Supplies
# 2      OH      5         1  2/15/2021  Office Supplies
# 3      OH      5         1  2/15/2021  Office Supplies
# 4      OH      5         1  2/15/2021  Office Supplies
# ..    ...    ...       ...        ...              ...
# 211    DC    300         4   1/9/2024      Electronics
# 212    DC    300         4   1/9/2024      Electronics
# 213    DC    300         4   1/9/2024      Electronics
# 214    DC    300         4   1/9/2024      Electronics
# 215    DC    300         4   1/9/2024      Electronics
#
# [216 rows x 5 columns]

# %%
ddf.groupby('State').max()
# Out:
#        Sales  Quantity Order_Date         Category
# State
# CA       350         3  8/17/2021  Office Supplies
# DC       700         4  7/18/2023  Office Supplies
# FL       700         3  7/18/2021        Furniture
# GA       850         4  5/22/2021  Office Supplies
# IL       800         4  9/30/2023        Furniture
# OH       600         4  9/20/2021  Office Supplies
# TX       900         4  9/15/2022        Furniture
# UT       450         4   9/9/2022  Office Supplies
# WA       150         3  6/14/2022  Office Supplies

# %%
ddf.groupby('State').max().sort_values(by='Sales',ascending=False)
# Out:
#        Sales  Quantity Order_Date         Category
# State
# TX       900         4  9/15/2022        Furniture
# GA       850         4  5/22/2021  Office Supplies
# IL       800         4  9/30/2023        Furniture
# DC       700         4  7/18/2023  Office Supplies
# FL       700         3  7/18/2021        Furniture
# OH       600         4  9/20/2021  Office Supplies
# UT       450         4   9/9/2022  Office Supplies
# CA       350         3  8/17/2021  Office Supplies
# WA       150         3  6/14/2022  Office Supplies

# %% [markdown]
# ### from the table above we can notice that most sales occured in the month of May,July, ,September according to the order date
# ### the item that had the most sales is Furnitures and Office supplies
# ### Sales are good in TX ,DC,GA,IL
#
# ## RECOMMENDATION
# ### More furnitures and office supplies should be introduced in he weak regions and state
# ### More can advertisement or branches can be intorduced to the weak and strong regions also

# %%
pd.set_option('display.max.rows',216)

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\SalesStore.csv")

# %%
df
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region  \
# 0     2/15/2021   2/20/2021    Ground        44104  Midwest
# 1     2/15/2021   2/20/2021    Ground        44104  Midwest
# 2     2/15/2021   2/20/2021    Ground        44104  Midwest
# 3     2/15/2021   2/20/2021    Ground        44104  Midwest
# 4     2/15/2021   2/20/2021    Ground        44104  Midwest
# 5     3/10/2021   3/15/2021       Air        75201    South
# 6     3/10/2021   3/15/2021       Air        75201    South
# 7     3/10/2021   3/15/2021       Air        75201    South
# 8     3/10/2021   3/15/2021       Air        75201    South
# 9     3/10/2021   3/15/2021       Air        75201    South
# 10    3/10/2021   3/15/2021       Air        75201    South
# 11     4/6/2021   4/11/2021       Air        33102    South
# 12     4/6/2021   4/11/2021       Air        33102    South
# 13     4/6/2021   4/11/2021       Air        33102    South
# 14     4/6/2021   4/11/2021       Air        33102    South
# ...

# %%
df.set_index('Order_Date',inplace=True)

# %%
df
# Out:
#              Ship_Date Ship_Mode  Postal_Code   Region  Product_Reference  \
# Order_Date
# 2/15/2021    2/20/2021    Ground        44104  Midwest   OFF-TAP-10022901
# 2/15/2021    2/20/2021    Ground        44104  Midwest   OFF-TAP-10023012
# 2/15/2021    2/20/2021    Ground        44104  Midwest   OFF-TAP-10002828
# 2/15/2021    2/20/2021    Ground        44104  Midwest   OFF-TAP-10022901
# 2/15/2021    2/20/2021    Ground        44104  Midwest   OFF-TAP-10000482
# 3/10/2021    3/15/2021       Air        75201    South    FUR-CH-10000454
# 3/10/2021    3/15/2021       Air        75201    South    FUR-CH-10000454
# 3/10/2021    3/15/2021       Air        75201    South    FUR-CH-10000454
# 3/10/2021    3/15/2021       Air        75201    South    FUR-CH-10000454
# 3/10/2021    3/15/2021       Air        75201    South    FUR-CH-10000454
# 3/10/2021    3/15/2021       Air        75201    South    FUR-CH-10000454
# ...

# %%
df[df['Category']=='Electronics'].sort_values(by=['Sales','Quantity'],ascending=[False,False])
# Out:
#              Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# Order_Date
# 11/30/2022   12/5/2022    Ground        30305    South  ELE-LAP-10030789
# 11/30/2022   12/5/2022    Ground        30305    South  ELE-LAP-10031901
# 11/30/2022   12/5/2022    Ground        30305    South  ELE-LAP-10003636
# 11/30/2022   12/5/2022    Ground        30305    South  ELE-LAP-10000490
# 10/5/2021   10/12/2021    Ground        60601  Midwest  ELE-LAP-10003456
# 10/5/2021   10/12/2021    Ground        60601  Midwest  ELE-LAP-10003456
# 10/5/2021   10/12/2021    Ground        60601  Midwest  ELE-LAP-10003333
# 10/5/2021   10/12/2021    Ground        60601  Midwest  ELE-LAP-10004567
# 10/5/2021   10/12/2021    Ground        60601  Midwest  ELE-LAP-10003456
# 10/5/2021   10/12/2021    Ground        60601  Midwest  ELE-LAP-10000457
# 4/10/2022    4/15/2022    Ground        20005     East  ELE-SMA-10027456
# 4/10/2022    4/15/2022    Ground        20005     East  ELE-SMA-10028567
# ...

# %%
df2022=df[df['Ship_Date'].dt.strftime('%m/%d/%Y')=="2/15/2021"]
df2022
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df2022=df[df['Ship_Date'].dt.strftime('%m/%d/%Y')=="2/15/2021"]
#       2 df2022
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region  \
# 0     2/15/2021   2/20/2021    Ground        44104  Midwest
# 1     2/15/2021   2/20/2021    Ground        44104  Midwest
# 2     2/15/2021   2/20/2021    Ground        44104  Midwest
# 3     2/15/2021   2/20/2021    Ground        44104  Midwest
# 4     2/15/2021   2/20/2021    Ground        44104  Midwest
# 5     3/10/2021   3/15/2021       Air        75201    South
# 6     3/10/2021   3/15/2021       Air        75201    South
# 7     3/10/2021   3/15/2021       Air        75201    South
# 8     3/10/2021   3/15/2021       Air        75201    South
# 9     3/10/2021   3/15/2021       Air        75201    South
# 10    3/10/2021   3/15/2021       Air        75201    South
# 11     4/6/2021   4/11/2021       Air        33102    South
# 12     4/6/2021   4/11/2021       Air        33102    South
# 13     4/6/2021   4/11/2021       Air        33102    South
# 14     4/6/2021   4/11/2021       Air        33102    South
# ...

# %%
# to get details of transactions that happened 3/10/2021

date=df["Order_Date"]=='3/10/2021'

# %%
df.loc[date]
# Out:
#    Order_Date  Ship_Date Ship_Mode  Postal_Code Region Product_Reference  \
# 5   3/10/2021  3/15/2021       Air        75201  South   FUR-CH-10000454
# 6   3/10/2021  3/15/2021       Air        75201  South   FUR-CH-10000454
# 7   3/10/2021  3/15/2021       Air        75201  South   FUR-CH-10000454
# 8   3/10/2021  3/15/2021       Air        75201  South   FUR-CH-10000454
# 9   3/10/2021  3/15/2021       Air        75201  South   FUR-CH-10000454
# 10  3/10/2021  3/15/2021       Air        75201  South   FUR-CH-10000454
#
#        Category Sub_Category  Sales  Quantity  Profit State
# 5   Electronics       Phones    500         2    10.0    TX
# 6   Electronics       Phones    500         2    10.0    TX
# 7     Furniture       Chairs    500         2    10.0    TX
# 8     Furniture       Chairs    500         2    10.0    TX
# 9   Electronics       Phones    500         2    10.0    TX
# 10  Electronics       Phones    500         2    10.0    TX

# %%
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'], format='%m/%d/%Y')

# %%
df['Ship_Date']
# Out:
# 0     2021-02-20
# 1     2021-02-20
# 2     2021-02-20
# 3     2021-02-20
# 4     2021-02-20
# 5     2021-03-15
# 6     2021-03-15
# 7     2021-03-15
# 8     2021-03-15
# 9     2021-03-15
# 10    2021-03-15
# 11    2021-04-11
# 12    2021-04-11
# 13    2021-04-11
# 14    2021-04-11
# 15    2021-04-11
# 16    2021-04-11
# 17    2021-05-08
# 18    2021-05-08
# 19    2021-05-08
# 20    2021-05-08
# 21    2021-05-08
# 22    2021-05-28
# 23    2021-05-28
# 24    2021-05-28
# 25    2021-05-28
# 26    2021-05-28
# 27    2021-05-28
# 28    2021-06-30
# 29    2021-06-30
# 30    2021-06-30
# 31    2021-06-30
# 32    2021-06-30
# 33    2021-06-30
# 34    2021-07-23
# 35    2021-07-23
# 36    2021-07-23
# 37    2021-07-23
# 38    2021-07-23
# 39    2021-08-20
# 40    2021-08-20
# 41    2021-08-20
# 42    2021-08-20
# 43    2021-08-20
# 44    2021-08-20
# 45    2021-09-25
# 46    2021-09-25
# 47    2021-09-25
# 48    2021-09-25
# 49    2021-09-25
# 50    2021-09-25
# 51    2021-10-12
# ...

# %%
df
# Out:
#      Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  Product_Reference  \
# 0     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10022901
# 1     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10023012
# 2     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10002828
# 3     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10022901
# 4     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10000482
# 5     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 6     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 7     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 8     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 9     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 10    3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# ...

# %%
ship_date_year2022=df[df['Ship_Date'].dt.strftime('%Y')=="2022"]

# %%
ship_date_year2022
# Out:
#      Order_Date  Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 68    1/18/2022 2022-01-25    Ground        20001     East  OFF-PEN-10004567
# 69    1/18/2022 2022-01-25    Ground        20001     East  OFF-PEN-10004567
# 70    1/18/2022 2022-01-25    Ground        20001     East  OFF-PEN-10004444
# 71    1/18/2022 2022-01-25    Ground        20001     East  OFF-PEN-10005678
# 72    1/18/2022 2022-01-25    Ground        20001     East  OFF-PEN-10004567
# 73    1/18/2022 2022-01-25    Ground        20001     East  OFF-PEN-10000458
# 74    1/24/2022 2022-01-30       Air        60605  Midwest  FUR-DES-10026345
# 75    1/24/2022 2022-01-30       Air        60605  Midwest  FUR-DES-10027456
# 76    1/24/2022 2022-01-30       Air        60605  Midwest  FUR-DES-10003232
# 77    1/24/2022 2022-01-30       Air        60605  Midwest  FUR-DES-10026345
# 78    1/24/2022 2022-01-30       Air        60605  Midwest  FUR-DES-10000486
# ...

# %%
# to get thedetails of shipment in april  year 2022

april=ship_date_year2022[ship_date_year2022['Ship_Date'].dt.strftime('%Y-%m')=='2022-04']

# %%
april
# Out:
#    Order_Date  Ship_Date Ship_Mode  Postal_Code Region Product_Reference  \
# 85   4/3/2022 2022-04-10       Air        33101  South  FUR-TAB-10005678
# 86   4/3/2022 2022-04-10       Air        33101  South  FUR-TAB-10005678
# 87   4/3/2022 2022-04-10       Air        33101  South  FUR-TAB-10005555
# 88   4/3/2022 2022-04-10       Air        33101  South  FUR-TAB-10007890
# 89   4/3/2022 2022-04-10       Air        33101  South  FUR-TAB-10005678
# 90   4/3/2022 2022-04-10       Air        33101  South  FUR-TAB-10000459
# 91  4/10/2022 2022-04-15    Ground        20005   East  ELE-SMA-10027456
# 92  4/10/2022 2022-04-15    Ground        20005   East  ELE-SMA-10028567
# 93  4/10/2022 2022-04-15    Ground        20005   East  ELE-SMA-10003333
# 94  4/10/2022 2022-04-15    Ground        20005   East  ELE-SMA-10000487
#
#        Category Sub_Category  Sales  Quantity  Profit State
# 85    Furniture       Tables    400         1     8.0    FL
# ...

# %%
df
# Out:
#      Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  Product_Reference  \
# 0     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10022901
# 1     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10023012
# 2     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10002828
# 3     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10022901
# 4     2/15/2021 2021-02-20    Ground        44104  Midwest   OFF-TAP-10000482
# 5     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 6     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 7     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 8     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 9     3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# 10    3/10/2021 2021-03-15       Air        75201    South    FUR-CH-10000454
# ...

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
df
# Out:
#     Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  Product_Reference  \
# 0   2021-02-15 2021-02-20    Ground        44104  Midwest   OFF-TAP-10022901
# 1   2021-02-15 2021-02-20    Ground        44104  Midwest   OFF-TAP-10023012
# 2   2021-02-15 2021-02-20    Ground        44104  Midwest   OFF-TAP-10002828
# 3   2021-02-15 2021-02-20    Ground        44104  Midwest   OFF-TAP-10022901
# 4   2021-02-15 2021-02-20    Ground        44104  Midwest   OFF-TAP-10000482
# 5   2021-03-10 2021-03-15       Air        75201    South    FUR-CH-10000454
# 6   2021-03-10 2021-03-15       Air        75201    South    FUR-CH-10000454
# 7   2021-03-10 2021-03-15       Air        75201    South    FUR-CH-10000454
# 8   2021-03-10 2021-03-15       Air        75201    South    FUR-CH-10000454
# 9   2021-03-10 2021-03-15       Air        75201    South    FUR-CH-10000454
# 10  2021-03-10 2021-03-15       Air        75201    South    FUR-CH-10000454
# ...

# %% [markdown]
# #### transactions in year 2022

# %%
y2022=df[df['Order_Date'].dt.strftime('%Y')=='2022']

# %%
y2022
# Out:
#     Order_Date  Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 68  2022-01-18 2022-01-25    Ground        20001     East  OFF-PEN-10004567
# 69  2022-01-18 2022-01-25    Ground        20001     East  OFF-PEN-10004567
# 70  2022-01-18 2022-01-25    Ground        20001     East  OFF-PEN-10004444
# 71  2022-01-18 2022-01-25    Ground        20001     East  OFF-PEN-10005678
# 72  2022-01-18 2022-01-25    Ground        20001     East  OFF-PEN-10004567
# 73  2022-01-18 2022-01-25    Ground        20001     East  OFF-PEN-10000458
# 74  2022-01-24 2022-01-30       Air        60605  Midwest  FUR-DES-10026345
# 75  2022-01-24 2022-01-30       Air        60605  Midwest  FUR-DES-10027456
# 76  2022-01-24 2022-01-30       Air        60605  Midwest  FUR-DES-10003232
# 77  2022-01-24 2022-01-30       Air        60605  Midwest  FUR-DES-10026345
# 78  2022-01-24 2022-01-30       Air        60605  Midwest  FUR-DES-10000486
# ...

# %%
yg=y2022.groupby('Category').Sales.max()

# %%
yg
# Out:
# Category
# Electronics        850
# Furniture          600
# Office Supplies    120
# Name: Sales, dtype: int64

# %%
y2022.groupby('Category').max()
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code Region  \
# Category
# Electronics     2022-11-30 2022-12-05    Ground        98101   West
# Furniture       2022-11-27 2022-12-03    Ground        75206  South
# Office Supplies 2022-09-09 2022-09-15    Ground        90003   West
#
#                 Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# Electronics      ELE-SMA-10028567  Smartphones    850         4    17.0    WA
# Furniture        FUR-TAB-10030789       Tables    600         4    12.0    TX
# Office Supplies  OFF-PEN-10029678         Pens    120         4     2.4    WA

# %% [markdown]
# #### the total number of transaction year 2022

# %%
y2022.groupby('Order_Date').Sales.count()
# Out:
# Order_Date
# 2022-01-18    6
# 2022-01-24    5
# 2022-02-25    6
# 2022-04-03    6
# 2022-04-10    4
# 2022-05-11    5
# 2022-06-14    6
# 2022-06-23    4
# 2022-07-29    5
# 2022-09-09    6
# 2022-09-15    4
# 2022-10-18    5
# 2022-11-27    6
# 2022-11-30    4
# Name: Order_Date, dtype: int64

# %%
y2022.groupby('Category').Sales.count()
# Out:
# Category
# Electronics        25
# Furniture          26
# Office Supplies    21
# Name: Sales, dtype: int64

# %% [markdown]
# ##### products that had lowest sales in 2022

# %%
y2022.groupby('Category').min()
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  \
# Category
# Electronics     2022-02-25 2022-03-02       Air        20003     East
# Furniture       2022-01-24 2022-01-30       Air        33101  Midwest
# Office Supplies 2022-01-18 2022-01-25       Air        20001     East
#
#                 Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# Electronics      ELE-CAM-10000475      Cameras    150         3     3.0    DC
# Furniture        FUR-BOO-10000462    Bookcases    250         1     5.0    FL
# Office Supplies  OFF-ENV-10000473    Envelopes     15         2     0.3    DC

# %%
y2024=df[df['Order_Date'].dt.strftime('%Y')=='2024']

# %%
y2024
# Out:
#     Order_Date  Ship_Date Ship_Mode  Postal_Code Region Product_Reference  \
# 211 2024-01-09 2024-01-14    Ground        20004   East  ELE-PRI-10021890
# 212 2024-01-09 2024-01-14    Ground        20004   East  ELE-PRI-10022901
# 213 2024-01-09 2024-01-14    Ground        20004   East  ELE-PRI-10002727
# 214 2024-01-09 2024-01-14    Ground        20004   East  ELE-PRI-10021890
# 215 2024-01-09 2024-01-14    Ground        20004   East  ELE-PRI-10000481
#
#         Category Sub_Category  Sales  Quantity  Profit State
# 211  Electronics     Printers    300         4     6.0    DC
# 212  Electronics     Printers    300         4     6.0    DC
# 213  Electronics     Printers    300         4     6.0    DC
# 214  Electronics     Printers    300         4     6.0    DC
# 215  Electronics     Printers    300         4     6.0    DC

# %%
y2024.groupby('Category').max()
# Out:
#             Order_Date  Ship_Date Ship_Mode  Postal_Code Region  \
# Category
# Electronics 2024-01-09 2024-01-14    Ground        20004   East
#
#             Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# Electronics  ELE-PRI-10022901     Printers    300         4     6.0    DC

# %% [markdown]
# #### total transctions in 2024

# %%
y2024.groupby('Category').Sales.count()
# Out:
# Category
# Electronics    5
# Name: Sales, dtype: int64

# %%
y2023=df[df['Order_Date'].dt.strftime('%Y')=='2023']

# %%
y2023
# Out:
#     Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  Product_Reference  \
# 140 2023-01-02 2023-01-08    Ground        44103  Midwest   OFF-GLU-10016345
# 141 2023-01-02 2023-01-08    Ground        44103  Midwest   OFF-GLU-10017345
# 142 2023-01-02 2023-01-08    Ground        44103  Midwest   OFF-GLU-10002222
# 143 2023-01-02 2023-01-08    Ground        44103  Midwest   OFF-GLU-10016345
# 144 2023-01-02 2023-01-08    Ground        44103  Midwest   OFF-GLU-10000476
# 145 2023-02-08 2023-02-14       Air        75202    South   ELE-SMA-10009012
# 146 2023-02-08 2023-02-14       Air        75202    South   ELE-SMA-10009012
# 147 2023-02-08 2023-02-14       Air        75202    South   ELE-SMA-10009999
# 148 2023-02-08 2023-02-14       Air        75202    South   ELE-SMA-10011234
# 149 2023-02-08 2023-02-14       Air        75202    South   ELE-SMA-10009012
# 150 2023-02-08 2023-02-14       Air        75202    South   ELE-SMA-10000463
# ...

# %% [markdown]
# #### transactions in year 2023

# %%
y2023.groupby('Category').max()
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code Region  \
# Category
# Electronics     2023-09-30 2023-10-05    Ground        75202  South
# Furniture       2023-10-28 2023-11-02       Air        90002   West
# Office Supplies 2023-12-11 2023-12-18    Ground        90004   West
#
#                 Product_Reference       Sub_Category  Sales  Quantity  Profit  \
# Category
# Electronics      ELE-SMA-10011234       Smartwatches    280         4     5.6
# Furniture        FUR-OUT-10018456  Outdoor Furniture    550         3    11.0
# Office Supplies  OFF-STP-10035345           Staplers    100         4     2.0
#
#                 State
# Category
# Electronics        TX
# Furniture          TX
# Office Supplies    UT

# %%
y2023.groupby('Category').min()
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  \
# Category
# Electronics     2023-02-08 2023-02-14       Air        20006     East
# Furniture       2023-03-17 2023-03-24       Air        60604  Midwest
# Office Supplies 2023-01-02 2023-01-08       Air        20002     East
#
#                 Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# Electronics      ELE-ACC-10000478  Accessories    100         1     2.0    DC
# Furniture        FUR-BOO-10000492    Bookcases    180         2     3.6    CA
# Office Supplies  OFF-GLU-10000476         Glue      8         1     0.2    CA

# %%
y2023.groupby('Category').Sales.count()
# Out:
# Category
# Electronics        21
# Furniture          20
# Office Supplies    30
# Name: Sales, dtype: int64

# %%
y2023.groupby('Category').Quantity.count()
# Out:
# Category
# Electronics        21
# Furniture          20
# Office Supplies    30
# Name: Quantity, dtype: int64

# %% [markdown]
# #### transactions in 2021

# %%
y2021=df[df['Order_Date'].dt.strftime('%Y')=='2021']

# %%
y2021
# Out:
#    Order_Date  Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0  2021-02-15 2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 1  2021-02-15 2021-02-20    Ground        44104  Midwest  OFF-TAP-10023012
# 2  2021-02-15 2021-02-20    Ground        44104  Midwest  OFF-TAP-10002828
# 3  2021-02-15 2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 4  2021-02-15 2021-02-20    Ground        44104  Midwest  OFF-TAP-10000482
# 5  2021-03-10 2021-03-15       Air        75201    South   FUR-CH-10000454
# 6  2021-03-10 2021-03-15       Air        75201    South   FUR-CH-10000454
# 7  2021-03-10 2021-03-15       Air        75201    South   FUR-CH-10000454
# 8  2021-03-10 2021-03-15       Air        75201    South   FUR-CH-10000454
# 9  2021-03-10 2021-03-15       Air        75201    South   FUR-CH-10000454
# 10 2021-03-10 2021-03-15       Air        75201    South   FUR-CH-10000454
# ...

# %%
y2021.groupby('Category').max()
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code Region  \
# Category
# Electronics     2021-10-05 2021-10-12    Ground        84102   West
# Furniture       2021-11-12 2021-11-17    Ground        90001   West
# Office Supplies 2021-10-11 2021-10-16    Ground        84104   West
#
#                 Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# Electronics       FUR-CH-10000454      Tablets    800         2    16.0    UT
# Furniture        FUR-SOF-10016578        Sofas    900         4    18.0    TX
# Office Supplies  OFF-TAP-10023012         Tape    100         4     2.0    UT

# %%
y2021.groupby('Category').min()
# Out:
#                 Order_Date  Ship_Date Ship_Mode  Postal_Code   Region  \
# Category
# Electronics     2021-03-10 2021-03-15       Air        33104  Midwest
# Furniture       2021-03-10 2021-03-15       Air        33102    South
# Office Supplies 2021-02-15 2021-02-20       Air        30301  Midwest
#
#                 Product_Reference Sub_Category  Sales  Quantity  Profit State
# Category
# Electronics      ELE-LAP-10000457      Laptops    120         2    2.40    FL
# Furniture        FUR-BED-10000471         Beds    200         2    4.00    CA
# Office Supplies  OFF-ERA-10000485      Erasers      5         1    0.15    GA

# %%
y2021.groupby('Category').Sales.count()
# Out:
# Category
# Electronics        21
# Furniture          25
# Office Supplies    22
# Name: Sales, dtype: int64
